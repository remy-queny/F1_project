# %%
import pandas as pd
import requests

# %% [markdown]
# # Exploration

# %%
url = "https://api.jolpi.ca/ergast/f1/current/drivers.json"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    liste_pilotes = data["MRData"]["DriverTable"]["Drivers"]
    df_drivers = pd.DataFrame(liste_pilotes)
    display(df_drivers)
else:
    print(f"Erreur : {response.status_code}")
# Out:
#               driverId permanentNumber code  \
# 0                albon              23  ALB
# 1               alonso              14  ALO
# 2            antonelli              12  ANT
# 3            paul_aron             NaN  NaN
# 4              bearman              87  BEA
# 5       dino_beganovic             NaN  NaN
# 6            bortoleto               5  BOR
# 7               bottas              77  BOT
# 8        luke_browning             NaN  NaN
# 9            colapinto              43  COL
# 10        jak_crawford             NaN  NaN
# 11  leonardo_fornaroli             NaN  NaN
# 12               gasly              10  GAS
# 13              hadjar               6  HAD
# 14            hamilton              44  HAM
# 15        colton_herta             NaN  NaN
# 16        ryo_hirakawa             NaN  NaN
# 17          hulkenberg              27  HUL
# 18         ayumu_iwasa             NaN  NaN
# 19              lawson              30  LAW
# 20             leclerc              16  LEC
# 21      arvid_lindblad              41  LIN
# 22              norris               1  NOR
# 23                ocon              31  OCO
# 24             piastri              81  PIA
# 25               perez              11  PER
# 26             russell              63  RUS
# 27               sainz              55  SAI
# 28              stroll              18  STR
# 29             tsunoda              22  TSU
#
#                                                   url    givenName  \
# 0        http://en.wikipedia.org/wiki/Alexander_Albon    Alexander
# 1        http://en.wikipedia.org/wiki/Fernando_Alonso     Fernando
# 2   https://en.wikipedia.org/wiki/Andrea_Kimi_Anto...  Andrea Kimi
# 3                                                 NaN         Paul
# 4         http://en.wikipedia.org/wiki/Oliver_Bearman       Oliver
# 5                                                 NaN         Dino
# 6     https://en.wikipedia.org/wiki/Gabriel_Bortoleto      Gabriel
# 7        http://en.wikipedia.org/wiki/Valtteri_Bottas     Valtteri
# 8                                                 NaN         Luke
# 9       http://en.wikipedia.org/wiki/Franco_Colapinto       Franco
# 10                                                NaN          Jak
# 11                                                NaN     Leonardo
# 12          http://en.wikipedia.org/wiki/Pierre_Gasly       Pierre
# 13         https://en.wikipedia.org/wiki/Isack_Hadjar        Isack
# 14        http://en.wikipedia.org/wiki/Lewis_Hamilton        Lewis
# 15                                                NaN       Colton
# 16                                                NaN          Ryo
# 17  http://en.wikipedia.org/wiki/Nico_H%C3%BClkenberg         Nico
# 18                                                NaN        Ayumu
# 19           http://en.wikipedia.org/wiki/Liam_Lawson         Liam
# 20       http://en.wikipedia.org/wiki/Charles_Leclerc      Charles
# 21       https://en.wikipedia.org/wiki/Arvid_Lindblad        Arvid
# 22          http://en.wikipedia.org/wiki/Lando_Norris        Lando
# 23          http://en.wikipedia.org/wiki/Esteban_Ocon      Esteban
# 24         http://en.wikipedia.org/wiki/Oscar_Piastri        Oscar
# 25     http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez       Sergio
# 26  http://en.wikipedia.org/wiki/George_Russell_(r...       George
# 27      http://en.wikipedia.org/wiki/Carlos_Sainz_Jr.       Carlos
# 28          http://en.wikipedia.org/wiki/Lance_Stroll        Lance
# 29          http://en.wikipedia.org/wiki/Yuki_Tsunoda         Yuki
#
#     familyName dateOfBirth    nationality
# 0        Albon  1996-03-23           Thai
# 1       Alonso  1981-07-29        Spanish
# 2    Antonelli  2006-08-25        Italian
# 3         Aron         NaN            NaN
# 4      Bearman  2005-05-08        British
# 5    Beganovic         NaN            NaN
# 6    Bortoleto  2004-10-14      Brazilian
# 7       Bottas  1989-08-28        Finnish
# 8     Browning         NaN            NaN
# 9    Colapinto  2003-05-27      Argentine
# 10    Crawford         NaN            NaN
# 11   Fornaroli         NaN            NaN
# 12       Gasly  1996-02-07         French
# 13      Hadjar  2004-09-28         French
# 14    Hamilton  1985-01-07        British
# 15       Herta         NaN            NaN
# 16    Hirakawa         NaN            NaN
# 17  Hülkenberg  1987-08-19         German
# 18       Iwasa         NaN            NaN
# 19      Lawson  2002-02-11  New Zealander
# 20     Leclerc  1997-10-16     Monegasque
# 21    Lindblad  2007-08-08        British
# 22      Norris  1999-11-13        British
# 23        Ocon  1996-09-17         French
# 24     Piastri  2001-04-06     Australian
# 25       Pérez  1990-01-26        Mexican
# 26     Russell  1998-02-15        British
# 27       Sainz  1994-09-01        Spanish
# 28      Stroll  1998-10-29       Canadian
# 29     Tsunoda  2000-05-11       Japanese

# %% [markdown]
# # Transformation

# %%
df_drivers.to_parquet('drivers_latest.parquet', index = False)
print("Fichier parquet généré.")
# Out:
# Fichier parquet généré.

# %% [markdown]
# # Chargement

# %%
from azure.storage.blob import BlobServiceClient
from dotenv import load_dotenv
import os

# %%
load_dotenv()

connection_string = os.getenv("AZURE_CONNECTION_STRING")
if not connection_string:
    raise ValueError("Erreur de lecture du fichier .env")

container_name = "bronze"
local_file_name = "drivers_latest.parquet"

blob_name = "drivers/drivers_latest.parquet"

# %%
blob_service_client = BlobServiceClient.from_connection_string(connection_string)
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
print("Debut de l'envoi vers le data lake")

with open(local_file_name, "rb") as data:
    blob_client.upload_blob(data, overwrite=True)

print("Fichier Parquet envoyé avec succès dans le dossier bronze")
# Out:
# Debut de l'envoi vers le data lake
# Fichier Parquet envoyé avec succès dans le dossier bronze

# %%
print(df_drivers.columns)
# Out:
# Index(['driverId', 'permanentNumber', 'code', 'url', 'givenName', 'familyName',
#        'dateOfBirth', 'nationality'],
#       dtype='str')
